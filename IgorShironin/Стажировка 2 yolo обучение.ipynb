# %%
from google.colab import drive
# Подключение Google Диска
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import  requests, zipfile
# !unzip -qo -x  "/content/drive/MyDrive/stajirovka/датсеты/3000-3099.zip" -d /content/img # Код, без информационных файлов"

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.228 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
import  requests, zipfile
# !unzip -qo -x  "/content/drive/MyDrive/stajirovka/stajirovka2/Yolo/yolo8n.zip" -d /content/yolo # Код, без информационных файлов"

# %%
from ultralytics import YOLO

# Initialize the model
model = YOLO('/content/yolo/detect/train/weights/best.pt')

# Train the model on MPS
results = model.train(data='/content/drive/MyDrive/stajirovka/stajirovka2/datasets/5613_5979/data.yaml', epochs=10, device='mps')
# Out:
# Ultralytics YOLOv8.0.228 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.00GHz)
# ...

# %%
# Для сохранения директории с файлами на свой Google Drive в Colab,
# можно использовать стандартный функционал библиотеки `google.colab`, а именно `drive` и `files`.
 # Вот пример кода:
# 1. Сохраняете текущую директорию с файлами в архив на свой гуглдиск:

import shutil

shutil.make_archive("/content/drive/MyDrive/stajirovka/stajirovka2/Yolo/yolo8n", 'zip', "/content/runs")

# # Вышеуказанный код создаст архив yolov8n.zip из директории `/content/runs` и сохранит его
# на свой Google Drive в директории `/content/drive/My Drive/model`.
# Out:
# '/content/drive/MyDrive/stajirovka/stajirovka2/Yolo/yolo8n.zip'

# %%
# Load the best checkpoint
model = YOLO('/content/yolo/detect/train/weights/best.pt')

# Evaluate the model on the validation set
metrics = model.val()
print('50-95: ', metrics.box.map)
print('50: ', metrics.box.map50)
print('75: ', metrics.box.map75)
# Out:
# Ultralytics YOLOv8.0.228 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3008378 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/stajirovka/stajirovka2/datasets/5613_5979/val/labels.cache... 62 images, 0 backgrounds, 0 corrupt: 100%|██████████| 62/62 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/4 [00:00<?, ?it/s]
# WARNING ⚠️ NMS time limit 1.300s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:14<00:00,  3.57s/it]
#                    all         62        868      0.989       0.75      0.812      0.715
#             01 Receipt         62         62      0.997      0.758      0.781      0.579
#   04-01 Counterparty 1         62         62       0.99      0.758      0.835      0.806
# ...

# %%
# Load the best checkpoint
model = YOLO('/content/runs/detect/train/weights/best.pt')

# Evaluate the model on the validation set
metrics = model.val()
print('50-95: ', metrics.box.map)
print('50: ', metrics.box.map50)
print('75: ', metrics.box.map75)
# Out:
# Ultralytics YOLOv8.0.228 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3008378 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/stajirovka/stajirovka2/datasets/5613_5979/val/labels.cache... 62 images, 0 backgrounds, 0 corrupt: 100%|██████████| 62/62 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:10<00:00,  2.62s/it]
#                    all         62        868      0.988      0.993      0.993      0.865
#             01 Receipt         62         62      0.968      0.991      0.993      0.714
#   04-01 Counterparty 1         62         62      0.982          1      0.995      0.941
#   04-02 Counterparty 2         62         62          1      0.997      0.995      0.854
#            05 Contract         62         62      0.983      0.916      0.981      0.691
# ...
