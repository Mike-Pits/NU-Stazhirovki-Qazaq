# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.151 🚀 Python-3.10.11 torch-2.0.1 CPU (Apple M1 Max)
# Setup complete ✅ (10 CPUs, 64.0 GB RAM, 598.5/7449.2 GB disk)

# %%
from ultralytics import YOLO

# Initialize the model
model = YOLO('yolov8s.pt')

# Train the model on MPS
results = model.train(data='/Users/pheonix/Desktop/AIU-qs-project/dataset/data.yaml', epochs=10, device='mps')
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 25.6MB/s]
# New https://pypi.org/project/ultralytics/8.0.220 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.151 🚀 Python-3.10.11 torch-2.0.1 MPS (Apple M1 Max)
# ...

# %%
# Load the best checkpoint
model = YOLO('/Users/pheonix/Desktop/AIU-qs-project/runs/detect/train/weights/best.pt')

# Evaluate the model on the validation set
metrics = model.val()
print('50-95: ', metrics.box.map)
print('50: ', metrics.box.map50)
print('75: ', metrics.box.map75)
# Out:
# Ultralytics YOLOv8.0.151 🚀 Python-3.10.11 torch-2.0.1 CPU (Apple M1 Max)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients
# val: Scanning /Users/pheonix/Desktop/AIU-qs-project/dataset/val/labels.cache... 120 images, 0 backgrounds, 0 corrupt: 100%|██████████| 120/120 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:44<00:00,  5.53s/it]
#                    all        120        360      0.994      0.987      0.994       0.86
#           20 Top Block        120        120          1      0.982      0.995      0.932
#        21 Middle Block        120        120      0.983      0.978      0.993      0.722
#        22 Bottom Block        120        120      0.997          1      0.995      0.925
# Speed: 0.4ms preprocess, 273.3ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to runs/detect/val3
# 50-95:  0.859721332933066
# 50:  0.9943920023084868
# ...
